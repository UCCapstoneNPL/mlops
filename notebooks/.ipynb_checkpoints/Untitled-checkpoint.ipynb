# %%
import os
import pandas as pd

# %% [markdown]
# path_parent = os.path.dirname(os.getcwd())
# file_path = os.path.join(path_parent, "data", "processed", "item_master_4_model_final.csv")
# df = pd.read_csv(file_path)

# %%
df.columns
# Out:
# Index(['ItemDescription', 'QuantitySold_Week1', 'QuantitySold_Week2',
#        'QuantitySold_Week3', 'QuantitySold_Week4', 'OnPromotion_Week1',
#        'OnPromotion_Week2', 'OnPromotion_Week3', 'OnPromotion_Week4',
#        'AdjustmentAmount_Week1', 'AdjustmentAmount_Week2',
#        'AdjustmentAmount_Week3', 'AdjustmentAmount_Week4', 'SalesSuccess'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                         count         mean          std    min    25%    50%  \
# QuantitySold_Week1       65.0  1239.323077  1258.155819  394.0  466.0  487.0
# QuantitySold_Week2       65.0  1208.907692  1193.517906  390.0  451.0  504.0
# QuantitySold_Week3       65.0  1268.769231  1319.483099  353.0  467.0  513.0
# QuantitySold_Week4       65.0  1226.215385  1233.686352  399.0  446.0  507.0
# OnPromotion_Week1        65.0   410.984615   418.124663  122.0  152.0  166.0
# OnPromotion_Week2        65.0   397.446154   396.724402  118.0  147.0  170.0
# OnPromotion_Week3        65.0   417.138462   432.988917  117.0  155.0  172.0
# OnPromotion_Week4        65.0   400.353846   402.010045  126.0  147.0  172.0
# AdjustmentAmount_Week1   65.0   312.261538    26.143998  251.0  297.0  314.0
# AdjustmentAmount_Week2   65.0   316.584615    21.724764  256.0  300.0  318.0
# AdjustmentAmount_Week3   65.0   311.800000    28.174235  261.0  293.0  309.0
# AdjustmentAmount_Week4   65.0   308.400000    22.742306  272.0  292.0  304.0
# SalesSuccess             65.0     0.107692     0.312404    0.0    0.0    0.0
#
#                            75%     max
# QuantitySold_Week1      1645.0  4584.0
# QuantitySold_Week2      1661.0  4542.0
# QuantitySold_Week3      1691.0  5213.0
# QuantitySold_Week4      1633.0  4716.0
# OnPromotion_Week1        547.0  1523.0
# OnPromotion_Week2        546.0  1554.0
# OnPromotion_Week3        549.0  1729.0
# OnPromotion_Week4        519.0  1540.0
# AdjustmentAmount_Week1   330.0   401.0
# AdjustmentAmount_Week2   332.0   360.0
# AdjustmentAmount_Week3   326.0   414.0
# AdjustmentAmount_Week4   323.0   367.0
# SalesSuccess               0.0     1.0

# %%
overview = df.describe()
overview.loc[["min", "max"]].to_json("schema_in.json")

# %%
class NotInRangeError(Exception):
    def __init__(self, message="Value not in range"):
        self.message = message
        super().__init__(self.message)

# %%
raise NotInRangeError
# Out:
# ---------------------------------------------------------------------------
# NotInRangeError                           Traceback (most recent call last)
# <ipython-input-26-93f531c6533c> in <module>
# ----> 1 raise NotInRangeError
#
# NotInRangeError: Value not in range
